# %%
# Task 1: Exploring and Visualizing the Iris Dataset

## Introduction
#The Iris dataset is a classic dataset in data science containing measurements of 150 
#iris flowers from 3 different species. In this notebook, we will explore, summarize, and 
#visualize the dataset to understand patterns and relationships between variables.

# %%
# Libraries import
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Iris dataset load
df = sns.load_dataset('iris')

# Dataset structure
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nFirst 5 rows:")
df.head()
# Out:
# Shape: (150, 5)
#
# Columns: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
#
# First 5 rows:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Dataset summary
print("Dataset Info:")
print(df.info())
print("\nBasic Statistics:")
df.describe()

# %%
# Scatter Plot — sepal length vs sepal width
plt.figure(figsize=(8, 5))
sns.scatterplot(x='sepal_length', y='sepal_width', 
                hue='species', data=df)
plt.title('Sepal Length vs Sepal Width')
plt.show()

# %%
# Histogram — Petal Length distribution
plt.figure(figsize=(8, 5))
sns.histplot(df['petal_length'], bins=20, kde=True)
plt.title('Petal Length Distribution')
plt.xlabel('Petal Length')
plt.ylabel('Count')
plt.show()

# %%
# Histogram — sepal Length distribution
plt.figure(figsize=(8, 5))
sns.histplot(df['sepal_length'], bins=20, kde=True)
plt.title('sepal Length Distribution')
plt.xlabel('sepal Length')
plt.ylabel('Count')
plt.show()

# %%
# Box Plot — Species wise comparison
plt.figure(figsize=(8, 5))
sns.boxplot(x='species', y='petal_length', data=df)
plt.title('Petal Length by Species')
plt.xlabel('Species')
plt.ylabel('Petal Length')
plt.show()

# %%
# Conclusion

# Iris dataset mein 150 flowers aur 3 species hain: Setosa, Versicolor, Virginica
# Setosa sabse choti petal length wali species hai
# Virginica sabse badi petal length wali species hai
# Petal length se teeno species clearly identify ki ja sakti hain
# Setosa aur Versicolor mein kuch outliers bhi mile
